# %% [markdown]
# <a href="https://colab.research.google.com/github/deepg7/NLP/blob/main/NLP_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
gender_features('Winston')
# Out:
# {'last_letter': 'n'}

# %%
import nltk
nltk.download('names')
from nltk.corpus import names
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.

# %%
labeled_names = ([(name, 'male') for name in names.words('male.txt')] + 
                 [(name, 'female') for name in names.words('female.txt')])

# %%
import random
random.shuffle(labeled_names)

# %%
featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
featuresets
# Out:
# [({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'u'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 't'}, 'female'),
#  ({'last_letter': 'e'}, 'male'),
#  ({'last_letter': 'u'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'y'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'p'}, 'female'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'r'}, 'male'),
#  ({'last_letter': 'l'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'g'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
# ...

# %%
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('Deep'))
# Out:
# 'male'

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.764
